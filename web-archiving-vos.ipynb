# %% [markdown]
# # Preserving Voice of the Shuttle

# %% [markdown]
# The purpose of this notebook is to parse out links from the html files located in the `vos-archive` directory. These files are a copy of the Voice of the Shuttle website generated with `wget` using the following command:
#
#     wget -mpkE --user-agent="mcburton@pitt.edu" --wait 1 http://vos.ucsb.edu
#
# This command created a directory with a giant pile of HTML files.

# %% [markdown]
# The number of HTML files generated by the web scrape:

# %%
ls vos-archive/ |wc -l
# Out:
#     7446

# %% [markdown]
# What the files produced by the web scrape look like:

# %%
ls -l vos-archive/ | head -n20
# Out:
# total 209592
# -rw-r--r--@  1 mcburton  staff     7261 Jun 18 11:41 about.asp.html
# -rw-r--r--@  1 mcburton  staff    10630 Jun 18 11:41 browse.asp?id=10.html
# -rw-r--r--@  1 mcburton  staff    18410 Jun 18 11:41 browse.asp?id=100.html
# -rw-r--r--@  1 mcburton  staff     7200 Jun 18 11:41 browse.asp?id=1003.html
# -rw-r--r--@  1 mcburton  staff     7534 Jun 18 11:41 browse.asp?id=1004.html
# -rw-r--r--@  1 mcburton  staff     7377 Jun 18 11:41 browse.asp?id=1005.html
# -rw-r--r--@  1 mcburton  staff    14874 Jun 18 11:41 browse.asp?id=1007.html
# -rw-r--r--@  1 mcburton  staff     8272 Jun 18 11:41 browse.asp?id=1008.html
# -rw-r--r--@  1 mcburton  staff    36002 Jun 18 11:41 browse.asp?id=1009.html
# -rw-r--r--@  1 mcburton  staff    46091 Jun 18 11:41 browse.asp?id=101.html
# -rw-r--r--@  1 mcburton  staff     8223 Jun 18 11:41 browse.asp?id=1010.html
# -rw-r--r--@  1 mcburton  staff    19638 Jun 18 11:41 browse.asp?id=1011.html
# ...
